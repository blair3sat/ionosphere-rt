# %% [markdown]
# # Kepler problem
# This is a test of building complex dynamic ODE systems like those required for raytracing the ionosonde path

# %%
using OrdinaryDiffEq, LinearAlgebra, ForwardDiff, Plots; gr()
H(q,p) = norm(p)^2/2 - inv(norm(q))
L(q,p) = q[1]*p[2] - p[1]*q[2]

pdot(dp,p,q,params,t) = ForwardDiff.gradient!(dp, q->-H(q, p), q)
qdot(dq,p,q,params,t) = ForwardDiff.gradient!(dq, p-> H(q, p), p)

initial_position = [.4, 0]
initial_velocity = [0., 2.]
initial_cond = (initial_position, initial_velocity)
initial_first_integrals = (H(initial_cond...), L(initial_cond...))
tspan = (0,20.)
prob = DynamicalODEProblem(pdot, qdot, initial_velocity, initial_position, tspan)
# Out:
# ODEProblem with uType RecursiveArrayTools.ArrayPartition{Float64,Tuple{Array{Float64,1},Array{Float64,1}}} and tType Float64. In-place: true
# timespan: (0.0, 20.0)
# u0: [0.0, 2.0][0.4, 0.0]

# %% [markdown]
# Let's plot the orbit and check the energy and angular momentum variation. We know that energy and angular momentum should be constant, and they are also called first integrals.

# %%
sol = solve(prob, KahanLi6(), dt=1//10);

plot_orbit(sol) = plot(sol,vars=(3,4), lab="Orbit", title="Kepler Problem Solution")

function plot_first_integrals(sol, H, L)
    plot(initial_first_integrals[1].-map(u->H(u[2,:], u[1,:]), sol.u), lab="Energy variation", title="First Integrals")
    plot!(initial_first_integrals[2].-map(u->L(u[2,:], u[1,:]), sol.u), lab="Angular momentum variation")
end
analysis_plot(sol, H, L) = plot(plot_orbit(sol), plot_first_integrals(sol, H, L))
# Out:
# analysis_plot (generic function with 1 method)

# %%
analysis_plot(sol, H, L)

# %%
sol
# Out:
# retcode: Success
# Interpolation: 3rd order Hermite
# t: 201-element Array{Float64,1}:
#   0.0
#   0.1
#   0.2
#   0.30000000000000004
#   0.4
#   0.5
#   0.6
#   0.7
#   0.7999999999999999
#   0.8999999999999999
#   0.9999999999999999
#   1.0999999999999999
#   1.2
#   ⋮
#  18.9
#  19.0
#  19.1
#  19.200000000000003
#  19.300000000000004
#  19.400000000000006
#  19.500000000000007
#  19.60000000000001
#  19.70000000000001
#  19.80000000000001
#  19.900000000000013
#  20.0
# u: 201-element Array{RecursiveArrayTools.ArrayPartition{Float64,Tuple{Array{Float64,1},Array{Float64,1}}},1}:
#  [0.0, 2.0][0.4, 0.0]
#  [-0.5830949354540153, 1.8556656829703986][0.36982713146498514, 0.19503596514776078]
#  [-0.9788105843777312, 1.5274462532150213][0.28987830863610903, 0.36495974735762693]
#  [-1.17547762665905, 1.1751394486895783][0.18078065407309682, 0.4998457720618293]
#  [-1.2440239387295458, 0.8720450804540057][0.05902925334751511, 0.6016956802132387]
#  [-1.2441259417439434, 0.6289994697149073][-0.06577256855272472, 0.6762747102291482]
#  [-1.210142434136089, 0.4368770315976506][-0.188677607179601, 0.7291942568591364]
#  [-1.159918613868923, 0.28408169071815415][-0.30726896099260204, 0.7649583990935568]
#  [-1.1025329550493486, 0.16100716005909121][-0.42042727561865095, 0.7869985179897889]
#  [-1.0426125487031446, 0.06047044972523817][-0.5276934467175253, 0.7979089270264804]
#  [-0.9825151944316923, -0.022758868883269043][-0.6289451297136035, 0.7996679590411173]
#  [-0.9234208895280647, -0.09248838639359218][-0.7242305798111837, 0.7938060429529527]
#  [-0.8658868226760644, -0.151517201169175][-0.8136816696700298, 0.7815261914686751]
#  ⋮
#  [-0.3095121595079035, 1.9610684379065422][0.3921229950287739, 0.10022213899772213]
#  [-0.8105591628087587, 1.7015518536680816][0.3344439357279098, 0.28489752729944684]
#  [-1.098716456911235, 1.346039934784431][0.23728889974157688, 0.43741919204328894]
#  [-1.2216434770974676, 1.0146166139270498][0.12021680827053512, 0.5550113775144692]
#  [-1.2499499900381417, 0.7423750265723883][-0.003918416420213356, 0.6423528468283568]
#  [-1.2298310873691611, 0.5265058660314975][-0.12818281922639643, 0.7053724817632256]
#  [-1.1861148292768293, 0.3555788492114466][-0.24911096207713992, 0.7491505605432051]
#  [-1.1314960903670108, 0.2188164842264573][-0.36504892367796954, 0.7776241823022721]
#  [-1.0724336821492226, 0.10787192092148691][-0.47526538003987784, 0.7937719633967374]
#  [-1.0122234000273465, 0.016617787590286977][-0.579499110310746, 0.7998530690972269]
#  [-0.9525349461454056, -0.05939856743324051][-0.6777283550436937, 0.7976021348885407]
#  [-0.894185739649566, -0.12343221924182135][-0.7700512224747644, 0.78837185320841]
